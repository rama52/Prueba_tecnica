# %%
pip install earthengine-api==0.1.284

# %%
# Importar librerías
import ee
import folium
import pandas as pd
import matplotlib.pyplot as plt

# 0.1. Autenticación e Inicialización (Necesario solo una vez)
# ee.Authenticate() # Solo si es la primera vez
ee.Initialize() 

# 0.2. Definir Área de Estudio (Usando coordenadas de ejemplo o GeoJSON)
# (Reemplaza con tu polígono del Lote 4)
# geometry = ee.Geometry.Polygon([[[-63.81, -33.99], [-63.79, -33.99], [-63.79, -33.97], [-63.81, -33.97], [-63.81, -33.99]]])
# Out:
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# Cell In[1], line 9
#       5 import matplotlib.pyplot as plt
#       7 # 0.1. Autenticación e Inicialización (Necesario solo una vez)
#       8 # ee.Authenticate() # Solo si es la primera vez
# ----> 9 ee.Initialize()
#      11 # 0.2. Definir Área de Estudio (Usando coordenadas de ejemplo o GeoJSON)
#      12 # (Reemplaza con tu polígono del Lote 4)
#      13 # geometry = ee.Geometry.Polygon([[[-63.81, -33.99], [-63.79, -33.99], [-63.79, -33.97], [-63.81, -33.97], [-63.81, -33.99]]])
#
# File /usr/local/lib/python3.9/site-packages/ee/_utils.py:38, in accept_opt_prefix.<locals>.opt_fixed.<locals>.wrapper(*args, **kwargs)
#      36     if new_key not in kwargs:
#      37       kwargs[new_key] = old_key_val
# ---> 38 return func(*args, **kwargs)
#
# ...
