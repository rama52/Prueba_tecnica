# %%
# importaciones
import os
import pandas as pd
from sqlalchemy import create_engine

# %%
# -----------------------------
# 1️⃣ Configuración de conexión
# -----------------------------
db_host = os.getenv("POSTGRES_HOST", "localhost")
db_port = os.getenv("POSTGRES_PORT", 5432)
db_name = os.getenv("POSTGRES_DB", "agtech_db")
db_user = os.getenv("POSTGRES_USER", "postgres")
db_pass = os.getenv("POSTGRES_PASSWORD", "postgres")

# %%
# Cadena de conexión SQLAlchemy
engine = create_engine(f"postgresql+psycopg2://{db_user}:{db_pass}@{db_host}:{db_port}/{db_name}")

# %%
# -----------------------------
# 2️⃣ Carpeta con archivos parquet
# -----------------------------
data_folder = "/data"  # dentro del contenedor

if not os.path.exists(data_folder):
    raise FileNotFoundError(f"La carpeta {data_folder} no existe")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 7
#       4 data_folder = "/data"  # dentro del contenedor
#       6 if not os.path.exists(data_folder):
# ----> 7     raise FileNotFoundError(f"La carpeta {data_folder} no existe")
#
# FileNotFoundError: La carpeta /data no existe

# %%
# !ls /workspace
# !ls /data
# Out:
# load_parquet.ipynb  prueba.ipynb
# ls: cannot access '/data': No such file or directory

# %%
# importaciones
import os
import pandas as pd
from sqlalchemy import create_engine

# -----------------------------
# 1️⃣ Configuración de conexión
# -----------------------------
db_host = os.getenv("POSTGRES_HOST", "localhost")
db_port = os.getenv("POSTGRES_PORT", 5432)
db_name = os.getenv("POSTGRES_DB", "agtech_db")
db_user = os.getenv("POSTGRES_USER", "postgres")
db_pass = os.getenv("POSTGRES_PASSWORD", "postgres")

# Cadena de conexión SQLAlchemy
engine = create_engine(f"postgresql+psycopg2://{db_user}:{db_pass}@{db_host}:{db_port}/{db_name}")

# -----------------------------
# 2️⃣ Leer archivo Parquet
# -----------------------------
parquet_path = "./data\soy_performance_2019_2021_2023.parquet"  # cambia por tu ruta
df = pd.read_parquet(parquet_path)

print(f"Datos leídos: {df.shape[0]} filas, {df.shape[1]} columnas")
print(df.head())

# -----------------------------
# 3️⃣ Guardar en la base de datos
# -----------------------------
table_name = "soy_performance_2019_2021_2023"  # cambia según tu tabla

df.to_sql(table_name, engine, if_exists="replace", index=False)
print(f"Datos cargados en la tabla '{table_name}' correctamente")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 22
#      18 # -----------------------------
#      19 # 2️⃣ Leer archivo Parquet
#      20 # -----------------------------
#      21 parquet_path = "./data\soy_performance_2019_2021_2023.parquet"  # cambia por tu ruta
# ---> 22 df = pd.read_parquet(parquet_path)
#      24 print(f"Datos leídos: {df.shape[0]} filas, {df.shape[1]} columnas")
#      25 print(df.head())
#
# File /usr/local/lib/python3.9/site-packages/pandas/io/parquet.py:651, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     498 @doc(storage_options=_shared_docs["storage_options"])
#     499 def read_parquet(
#     500     path: FilePath | ReadBuffer[bytes],
#    (...)
#     508     **kwargs,
#     509 ) -> DataFrame:
#     510     """
# ...
